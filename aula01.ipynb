# %%
import pandas as pd
import matplotlib.pyplot as plt

#Origem da fonte de dados
URL_DADOS = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

#Realizando a leitura do conteúdo do arquivo empacotado
dados = pd.read_csv(URL_DADOS, compression = 'zip')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# O resultado mostra apenas dois domínios para a variável tratamento
# Sendo o domínio com_droga qualificador de manipulação com químicos puramenete
# Sendo o domínio com_controle qualificador de manipulação com simulações controladas
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Contagem em horas do tempo transcorrido (de exposição)
# Essa variação considera a possibilidade de manifestação de reação
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Informação não definida
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
com_droga = dados['tratamento'].value_counts()['com_droga']
com_controle = dados['tratamento'].value_counts()['com_controle']

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
data = {'ComDroga': [com_droga],
        'ComControle': [com_controle]
       }
  
df = pd.DataFrame(data,columns=['ComDroga','ComControle'])
print (df)
# Out:
#    ComDroga  ComControle
# 0     21948         1866

# %%
data = {'Tratamento': ['Com Droga','Com Controle'],
        'Quantidade': [com_droga, com_controle]
       }
  
df = pd.DataFrame(data,columns=['Tratamento','Quantidade'])
df.plot(x ='Tratamento', y='Quantidade', kind = 'bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-d204705f5c5c> in <module>()
#       5 df = pd.DataFrame(data,columns=['Tratamento','Quantidade'])
#       6 df.plot(x ='Tratamento', y='Quantidade', kind = 'bar')
# ----> 7 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df = pd.DataFrame({'Tr': [dados['tratamento'].unique()[0], dados['tratamento'].unique()[1]], 'Qua': [dados['tratamento'].value_counts()[0], dados['tratamento'].value_counts()[1]]})

ax = df.plot.barh(x='Tr', y='Qua')

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.barh()

# %%
barh = dados['tempo'].value_counts().plot.barh()
barh.set_title('Quantidade de tratamento por Tempo(Horas)')
barh.set_xlabel('Quantidade')
barh.set_ylabel('Tempo')
label = dados['tempo'].value_counts()

# %%
max = dados['g-0'].max()
min = dados['g-0'].min()

values = [max, min]

df = pd.DataFrame({'Dimensão': ['max', 'min'], 'Valores': [max, min]})

ax = df.plot.bar(x='Dimensão', y='Valores')
